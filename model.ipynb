# %% [markdown]
# <a href="https://colab.research.google.com/github/muneneee/talent/blob/dataset/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('talentassessment.csv')

# %%
data.head()
# Out:
#       Name sex              Grade  Percentage  \
# 0     John   M  E.E (Exceeds Exp)          91
# 1    Sarah   F     A.E (Appr Exp)          53
# 2  Michael   M    B.E (Below Exp)          22
# 3  Jessica   F     M.E (Meet Exp)          77
# 4    David   M     M.E (Meet Exp)          73
#
#                       Career Category  \
# 0  Science engineering and technology
# 1                     Social sciences
# 2              Arts and sport science
# 3  Science engineering and technology
# 4                     Social sciences
#
#                                             hobbie talents  \
# 0              Hiking, coding, playing video games  coding
# 1        Reading, painting, watching documentaries     art
# 2      Playing sports, drawing, listening to music  sports
# 3               Playing chess, hiking, programming  coding
# 4  Playing guitar, writing poetry, watching movies  poetry
#
#                  careerrecommendation
# 0  science engineering and technology
# ...

# %%
pip install ydata-profiling==4.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import libraries
import pandas as pd
from ydata_profiling import ProfileReport


# Produce and save the profiling report
profile = ProfileReport(data,title="HCC Profile Report")
profile.to_file("profile report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

data['hobbie']= label_encoder.fit_transform(data['hobbie'])
data['talents']= label_encoder.fit_transform(data['talents'])

data['Grade']= data['Grade'].map({'E.E (Exceeds Exp)':3, 'A.E (Appr Exp)':2, 'M.E (Meet Exp)':1, 'B.E (Below Exp)':0})
data['sex']= data['sex'].map({'M':0, 'F':1})
data['Career Category']= data['Career Category'].map({'Science engineering and technology':0, 'Social sciences':1, 'Arts and sport science':2})
data['careerrecommendation']= data['careerrecommendation'].map({'science engineering and technology':0, 'social sciences':1, 'arts and sports science':2, 'not qualified':3})

# %%
data
# Out:
#          Name  sex  Grade  Percentage  Career Category  hobbie  talents  \
# 0        John    0      3          91                0       3        3
# 1       Sarah    1      2          53                1      23        1
# 2     Michael    0      0          22                2      18       17
# 3     Jessica    1      1          77                0       9        3
# 4       David    0      1          73                1      13       15
# 5       Emily    1      2          60                2       0        4
# 6       James    0      3          83                0      20       13
# 7      Sophia    1      0          15                2       2        5
# 8      Daniel    0      2          57                1       7        8
# 9    Isabella    1      1          72                0      14       11
# 10      Ethan    0      3          94                1      12       10
# 11     Olivia    1      2          59                2       6        0
# ...

# %%
# DATA VISUALIZATION
import seaborn as sns

sns.boxplot(x="Percentage",data=data)
# Out:
# <AxesSubplot:xlabel='Percentage'>

# %%
# Saving the newly pre-processed data into a csv file for more chart and graph analysis

import numpy as np
data.to_csv('preprocessed_data.csv', index=False)

# %%
data.head()
# Out:
#       Name  sex  Grade  Percentage  Career Category  hobbie  talents  \
# 0     John    0    3.0          91                0       3        3
# 1    Sarah    1    2.0          53                1      23        1
# 2  Michael    0    0.0          22                2      18       17
# 3  Jessica    1    1.0          77                0       9        3
# 4    David    0    1.0          73                1      13       15
#
#    careerrecommendation
# 0                     0
# 1                     1
# 2                     2
# 3                     0
# 4                     1

# %%
import matplotlib.pyplot as plt
#plotting Percentage against names
plt.figure(figsize=[40,10])

#sns.scatterplot(data=data, x="periodcode", y="Bomet County")

# Add a regression line to the scatter plot
sns.barplot(data=data, x="Name", y="Percentage")
# sns.regplot(data=clean, x="periodcode", y="Bomet County")

# Customize the plot
plt.title(" Distribution of students against their percentage")
plt.xlabel("Name")
plt.ylabel("Percentage")

# Show the plot
plt.show()

# %%
#plotting a scatter graph of Percentage against names
plt.figure(figsize=[40,10])

sns.scatterplot(data=data, x="Name", y="Percentage")

# Customize the plot
plt.title(" Distribution of students against their percentages")
plt.xlabel("Name")
plt.ylabel("Percentage")

# Show the plot
plt.show()

# %%
plt.figure(figsize=[40,10])

sns.barplot(data=data, x="Career Category", y="Percentage")

# Customize the plot
plt.title(" Distribution of students against their percentages")
plt.xlabel("Career category")
plt.ylabel("Percentage")

# Show the plot
plt.show()
map=({'Science engineering and technology':0, 'Social sciences':1, 'Arts and sport science':2})

print(map)
# Out:
# {'Science engineering and technology': 0, 'Social sciences': 1, 'Arts and sport science': 2}

# %%
plt.figure(figsize=[40,10])

sns.barplot(data=data, x="Career Category", y="careerrecommendation")

# Customize the plot
plt.title(" Distribution of students against their percentages")
plt.xlabel("Career category")
plt.ylabel("careerrecommendation")

# Show the plot
plt.show()
map=({'Science engineering and technology':0, 'Social sciences':1, 'Arts and sport science':2})

print(map)
# Out:
# {'Science engineering and technology': 0, 'Social sciences': 1, 'Arts and sport science': 2}

# %%
# Split the data into training and testing sets
test_data = np.asarray(data[:15])
test_data

train_data = np.asarray(data[28:])
train_data
# Out:
# array([['Logan', 0, 1, 79, 2, 0, 4, 2],
#        ['Chloe', 1, 2, 61, 0, 20, 13, 0],
#        ['Samuel', 0, 3, 82, 1, 2, 5, 1],
#        ['Zoey', 1, 2, 54, 2, 7, 8, 2],
#        ['Jackson', 0, 0, 31, 0, 14, 11, 3],
#        ['Madison', 1, 1, 74, 1, 12, 6, 1],
#        ['Aiden', 0, 1, 76, 2, 6, 7, 2],
#        ['Lillian', 1, 2, 63, 0, 19, 13, 0],
#        ['Jayden', 0, 3, 96, 1, 1, 2, 1],
#        ['Natalie', 1, 0, 45, 2, 11, 10, 2],
#        ['Gabriel', 0, 1, 80, 0, 10, 3, 0],
#        ['Elizabeth', 1, 2, 51, 1, 22, 14, 1],
#        ['Caleb', 0, 3, 87, 2, 26, 15, 2],
#        ['Victoria', 1, 2, 56, 0, 24, 3, 0],
#        ['Isaac', 0, 0, 39, 1, 15, 7, 3]], dtype=object)

# %%
# decision tree model

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = pd.DataFrame(data.iloc[:,2:7])

# %%
X
# Out:
#     Grade  Percentage  Career Category  hobbie  talents
# 0       3          91                0       3        3
# 1       2          53                1      23        1
# 2       0          22                2      18       17
# 3       1          77                0       9        3
# 4       1          73                1      13       15
# 5       2          60                2       0        4
# 6       3          83                0      20       13
# 7       0          15                2       2        5
# 8       2          57                1       7        8
# 9       1          72                0      14       11
# 10      3          94                1      12       10
# 11      2          59                2       6        0
# 12      0          43                0      25       18
# 13      1          68                2       1        2
# 14      1          75                0      16       12
# 15      2          62                1       5        1
# ...

# %%
y = pd.DataFrame(data.iloc[:,7])

# %%
y
# Out:
#     careerrecommendation
# 0                      0
# 1                      1
# 2                      2
# 3                      0
# 4                      1
# 5                      2
# 6                      0
# 7                      2
# 8                      1
# 9                      0
# 10                     1
# 11                     2
# 12                     3
# 13                     2
# 14                     0
# 15                     1
# 16                     2
# 17                     3
# 18                     1
# 19                     2
# 20                     0
# 21                     1
# 22                     2
# 23                     0
# 24                     1
# 25                     2
# 26                     0
# 27                     3
# 28                     2
# 29                     0
# 30                     1
# 31                     2
# 32                     3
# 33                     1
# 34                     2
# 35                     0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=20,criterion='gini', random_state=1, max_depth=3)
classifier.fit(X_train,y_train)
# Out:
# <ipython-input-94-ac60475397de>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(X_train,y_train)
# RandomForestClassifier(max_depth=3, n_estimators=20, random_state=1)

# %% [markdown]
# ***Build Model***

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[4 0 0 0]
#  [0 5 2 0]
#  [0 0 8 0]
#  [0 1 0 2]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.83      0.71      0.77         7
#            2       0.80      1.00      0.89         8
#            3       1.00      0.67      0.80         3
#
#     accuracy                           0.86        22
#    macro avg       0.91      0.85      0.86        22
# weighted avg       0.87      0.86      0.86        22
#
# 0.8636363636363636

# %%
classifier.score(X_test, y_test)
# Out:
# 0.8636363636363636

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, cmap=plt.cm.Blues)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
